# %%
import pandas as pd
import numpy as np


df=pd.read_csv("학원data\성취도별 학교.csv",encoding='utf-8')
df
# Out:
#          1  광진구 중곡동  대원국제중학교     164명 100.00% 100.00%.1 100.00%.2 100.00%.3  \
# 0      NaN      NaN      NaN      NaN     NaN       NaN       NaN       NaN
# 1      2.0  강북구 미아동  영훈국제중학교     157명  98.30%    98.70%   100.00%    96.20%
# 2      NaN      NaN      NaN      NaN     NaN       NaN       NaN       NaN
# 3      3.0  강남구 수서동    대왕중학교     298명  97.60%    99.00%    97.70%    96.30%
# 4      NaN      NaN      NaN      NaN     NaN       NaN       NaN       NaN
# ..     ...      ...      ...      ...     ...       ...       ...       ...
# 759  381.0  양천구 신월동    양서중학교     174명  49.50%    69.00%    37.70%    42.00%
# 760    NaN      NaN      NaN      NaN     NaN       NaN       NaN       NaN
# 761  382.0  송파구 방이동  서울체육중학교      51명  45.70%    72.60%    51.00%    13.70%
# 762    NaN      NaN      NaN      NaN     NaN       NaN       NaN       NaN
# 763    NaN      NaN       평균  83,639명  77.90%    88.60%    75.00%    70.20%
#
#      27.10%       44명     162명
# ...

# %%
df.size
# Out:
# 8404

# %%
len(df.columns)
# Out:
# 11

# %%
df= pd.read_csv(학원data/성취도별 학교.csv, encoding='utf-8')
df
# Out:
#   Cell In[8], line 1
#     df= pd.read_csv(학원data/성취도별 학교.csv, encoding='utf-8')
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
